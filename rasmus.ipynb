# %%
from flask import Flask, render_template, redirect
from flask_pymongo import PyMongo
import pandas as pd
import urllib.request
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np

# %%
app = Flask(__name__)

# %%
from splinter import Browser
from bs4 import BeautifulSoup as soup
def init_browser():
    # @NOTE: Replace the path with your actual path to the chromedriver
    executable_path = {"executable_path": "C:\chrome_driver\chromedriver.exe"}
    return Browser("chrome", **executable_path, headless=False)

# %%
#  http://www.rasmussenreports.com/public_content/politics/trump_administration/trump_approval_index_history

# %%
import requests
url = urllib.request.urlopen("http://www.rasmussenreports.com/public_content/politics/trump_administration/trump_approval_index_history").read()
soup = soup(url,'html')

# %%
def p2f(x): # this is code i stole to strip percentages and convert to number, it also skips function if blank
    if not x:
        return x
    else:
        return float(x.strip('%'))/100

# %%
tables = soup.find('table')

i=0
# results = []
table = soup.find('table')
table_rows = table.find_all('tr')
date = []
ApprovalIndex =[]
StronglyApprove =[]
StronglyDisapprove =[]
TotalApprove =[]
TotalDisapprove =[]
for table in tables:
    rows = table.find("tr")
    for row in rows:
        cells = row.find("td")
print("")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-cf5d55486063> in <module>
#       3 for table in tables:
#       4     rows = table.find("tr")
# ----> 5     for row in rows:
#       6         cells = row.find("td")
#       7 print("")
#
# TypeError: 'int' object is not iterable

# %%
i=0
# results = []
table = soup.find('table')
table_rows = table.find_all('tr')
date = []
ApprovalIndex =[]
StronglyApprove =[]
StronglyDisapprove =[]
TotalApprove =[]
TotalDisapprove =[]

############################

for table in tables:
    rows = table.find_all("tr")
    for row in rows:
        cells = row.find_all("td")
        if len(cells) == 7:  # this filters out rows with 'Term', 'Instructor Name' etc.
            for cell in cells:
                print(cell.text + "\t", end="")  # \t is a Tab character, and end="" prevents a newline between cells
            print("")  # newline after each row

#soup = BeautifulSoup(FIU, "html.parser")


soup = BeautifulSoup(FIU, "lxml")

tables = soup.find_all('table')



##########################
for tr in table_rows:
    td = tr.find_all('td')
    #print(td.text)
    n =0
    row = []
    for i in td:
        a = i.text
        # this is where i need to put in a function that converrts the text to a usable date. 
        if n==2:    
            date.append(p2f(a))
        elif n ==6: 
            ApprovalIndex.append(p2f(a))
            n = n+1
        elif n ==7:
            StronglyApprove.append(p2f(a))
            n = n+1
        elif n==8:
            StronglyDisapprove.append(p2f(a))
            n = n+1
        elif n==9:
            TotalApprove.append(p2f(a))
            n = n+1
        elif n==10:
            TotalDisapprove.append(p2f(a))
            n = n+1
        else:
            n = n+1
    print(row)
    results.append(row)
    
    #row = [[i.text for i in td]]
#     row = []
#     i = 0
#     while i <= 20:
#         row.append(td)
#         i=i+1
#     # this injects all the texts from each spot in our row. 
# we have all the data, but we only want the first 20 columbs.
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
import requests
from bs4 import BeautifulSoup
import lxml


FIU = open('http://www.rasmussenreports.com/public_content/politics/trump_administration/trump_approval_index_history)
#soup = BeautifulSoup(FIU, "html.parser")


soup = BeautifulSoup(FIU, "lxml")

tables = soup.find_all('table')

for table in tables:
    rows = table.find_all("tr")
    for row in rows:
        cells = row.find_all("td")
        if len(cells) == 7:  # this filters out rows with 'Term', 'Instructor Name' etc.
            for cell in cells:
                print(cell.text + "\t", end="")  # \t is a Tab character, and end="" prevents a newline between cells
            print("")  # newline after each row



def p2f(x): return float(x.strip('%'))/100
percentage_list = []
for cell in cells:
    if '%' in cell.text:
        percentage_list.append(p2f(cell.text))
# Out:
#   File "<ipython-input-60-29f183fa8179>", line 6
#     FIU = open('http://www.rasmussenreports.com/public_content/politics/trump_administration/trump_approval_index_history)
#                                                                                                                           ^
# SyntaxError: EOL while scanning string literal

# %%
import requests
from bs4 import BeautifulSoup
import lxml


FIU = open('C://Users//joey//Desktop//response.txt','r').read()
#soup = BeautifulSoup(FIU, "html.parser")


soup = BeautifulSoup(FIU, "lxml")

tables = soup.find_all('table')

for table in tables:
    rows = table.find_all("tr")
    for row in rows:
        cells = row.find_all("td")
        if len(cells) == 7:  # this filters out rows with 'Term', 'Instructor Name' etc.
            for cell in cells:
                print(cell.text + "\t", end="")  # \t is a Tab character, and end="" prevents a newline between cells
            print("")  # newline after each row



def p2f(x): return float(x.strip('%'))/100
percentage_list = []
for cell in cells:
    if '%' in cell.text:
        percentage_list.append(p2f(cell.text))

# %%
import pandas as pd 
import numpy as np

# %%
dates.tail(22)
# Out:
#            date  BeginWeek
# 1012 2019-10-10 2019-10-09
# 1013 2019-10-11 2019-10-09
# 1014 2019-10-12 2019-10-09
# 1015 2019-10-13 2019-10-09
# 1016 2019-10-14 2019-10-09
# 1017 2019-10-15 2019-10-09
# 1018 2019-10-16 2019-10-16
# 1019 2019-10-17 2019-10-16
# 1020 2019-10-18 2019-10-16
# 1021 2019-10-19 2019-10-16
# 1022 2019-10-20 2019-10-16
# 1023 2019-10-21 2019-10-16
# 1024 2019-10-22 2019-10-16
# 1025 2019-10-23 2019-10-23
# 1026 2019-10-24 2019-10-23
# 1027 2019-10-25 2019-10-23
# 1028 2019-10-26 2019-10-23
# 1029 2019-10-27 2019-10-23
# 1030 2019-10-28 2019-10-23
# 1031 2019-10-29 2019-10-23
# 1032 2019-10-30 2019-10-30
# 1033 2019-10-31 2019-10-30
